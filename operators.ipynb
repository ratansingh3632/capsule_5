# %%
a=10
b=20
print(a+b)
print(a-b)
print(a/b)
print(a%b)
print(a**b)
a=-5
print(a)
a-=5
print(a)
a/=5
print(a)
a*=5
print(a)
a//=5
print(a)
a%=5
print(a)
# Out:
# 30
# -10
# 0.5
# 10
# 100000000000000000000
# -5
# -10
# -2.0
# -10.0
# -2.0
# 3.0

# %%
a=10
b=20
print(a>b)
print(a<b)
print(a==b)
print(a!=b)
print(a>=b)
print(a<=b)
# Out:
# False
# True
# False
# True
# False
# True

# %%
a>10 or a>11
# Out:
# False

# %%
a=100
b=100
print(a+b)
# Out:
# 200

# %%
a=10
b=20
print(a>b)
print(a<b)
print(a==b)
print(a!=b)
print(a>=b)
print(a<=b)
# Out:
# False
# True
# False
# True
# False
# True
